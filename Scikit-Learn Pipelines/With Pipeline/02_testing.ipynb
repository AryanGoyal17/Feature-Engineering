# %%
import pickle
import numpy as np 
import pandas as pd

# %%
pipeline = pickle.load(open('models/pipeline.pkl', 'rb'))

# %%
test_input = np.array([2, 'female', 30, 1, 0, 26.67, 'S'], dtype=object).reshape(1, 7)
test_input
# Out:
# array([[2, 'female', 30, 1, 0, 26.67, 'S']], dtype=object)

# %%
prediction = pipeline.predict(test_input)
prediction
# Out:
# c:\Users\aryan\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# c:\Users\aryan\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array([0])
